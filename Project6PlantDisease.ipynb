# %% [markdown]
# <a href="https://colab.research.google.com/github/aditih22/plant-disease-detection/blob/main/Project6PlantDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.**

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/MyDrive".
# !ls "/content/drive/MyDrive"
# Out:
#  Colab	'Colab Notebooks'   intel_image.h5

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %% [markdown]
# Now we will observe some of the images that are their in our dataset. We will plot **12 images** here using the matplotlib library.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Colab Notebooks/Plant_images_pianalytix/Potato-Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
#Converting Images to array
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# **Now we will convert all the images into numpy array.**

# %%
dir = "/content/drive/MyDrive/Colab Notebook/Plant_images_pianalytix"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# Name: count, dtype: int64

# %% [markdown]
# Next we will observe the shape of the image.

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# **Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).**

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 85, 85, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPoolin  (None, 42, 42, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231347 (903.70 KB)
# Trainable params: 231347 (903.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# **Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.**

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 40s 7s/step - loss: 1.0869 - accuracy: 0.3299 - val_loss: 1.0566 - val_accuracy: 0.3611
# Epoch 2/50
# 5/5 [==============================] - 43s 8s/step - loss: 1.0623 - accuracy: 0.3333 - val_loss: 1.0272 - val_accuracy: 0.3611
# Epoch 3/50
# 5/5 [==============================] - 57s 11s/step - loss: 1.0191 - accuracy: 0.3333 - val_loss: 0.9840 - val_accuracy: 0.3611
# Epoch 4/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.9791 - accuracy: 0.3333 - val_loss: 0.9404 - val_accuracy: 0.3819
# Epoch 5/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.9355 - accuracy: 0.4236 - val_loss: 0.8870 - val_accuracy: 0.4097
# Epoch 6/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.8842 - accuracy: 0.4983 - val_loss: 0.8327 - val_accuracy: 0.4792
# Epoch 7/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.8347 - accuracy: 0.4635 - val_loss: 0.7817 - val_accuracy: 0.6528
# Epoch 8/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.7831 - accuracy: 0.5955 - val_loss: 0.7263 - val_accuracy: 0.6319
# Epoch 9/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.7307 - accuracy: 0.6493 - val_loss: 0.6756 - val_accuracy: 0.6597
# Epoch 10/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.6816 - accuracy: 0.6441 - val_loss: 0.6269 - val_accuracy: 0.6944
# Epoch 11/50
# 5/5 [==============================] - 44s 9s/step - loss: 0.6368 - accuracy: 0.6632 - val_loss: 0.5809 - val_accuracy: 0.7014
# Epoch 12/50
# 5/5 [==============================] - 42s 8s/step - loss: 0.5890 - accuracy: 0.6719 - val_loss: 0.5352 - val_accuracy: 0.7222
# Epoch 13/50
# 5/5 [==============================] - 42s 9s/step - loss: 0.5471 - accuracy: 0.6701 - val_loss: 0.4946 - val_accuracy: 0.7153
# Epoch 14/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5099 - accuracy: 0.6701 - val_loss: 0.4628 - val_accuracy: 0.7222
# Epoch 15/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4807 - accuracy: 0.6667 - val_loss: 0.4299 - val_accuracy: 0.7292
# Epoch 16/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.4482 - accuracy: 0.6806 - val_loss: 0.4062 - val_accuracy: 0.7292
# Epoch 17/50
# 5/5 [==============================] - 53s 12s/step - loss: 0.4229 - accuracy: 0.6840 - val_loss: 0.3792 - val_accuracy: 0.7361
# Epoch 18/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.3972 - accuracy: 0.6892 - val_loss: 0.3608 - val_accuracy: 0.7431
# Epoch 19/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.3786 - accuracy: 0.6997 - val_loss: 0.3483 - val_accuracy: 0.7431
# Epoch 20/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.3589 - accuracy: 0.7153 - val_loss: 0.3183 - val_accuracy: 0.7500
# Epoch 21/50
# 5/5 [==============================] - 43s 8s/step - loss: 0.3372 - accuracy: 0.7396 - val_loss: 0.3031 - val_accuracy: 0.9375
# Epoch 22/50
# 5/5 [==============================] - 42s 9s/step - loss: 0.3174 - accuracy: 0.9809 - val_loss: 0.2825 - val_accuracy: 0.9375
# Epoch 23/50
# 5/5 [==============================] - 43s 9s/step - loss: 0.3023 - accuracy: 0.9844 - val_loss: 0.2671 - val_accuracy: 0.9375
# Epoch 24/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.2832 - accuracy: 0.9809 - val_loss: 0.2733 - val_accuracy: 0.9653
# Epoch 25/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.2656 - accuracy: 0.9913 - val_loss: 0.2353 - val_accuracy: 0.9514
# Epoch 26/50
# 5/5 [==============================] - 43s 9s/step - loss: 0.2351 - accuracy: 0.9948 - val_loss: 0.2342 - val_accuracy: 0.9792
# Epoch 27/50
# 5/5 [==============================] - 43s 8s/step - loss: 0.2122 - accuracy: 0.9931 - val_loss: 0.1955 - val_accuracy: 0.9583
# Epoch 28/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.1867 - accuracy: 0.9948 - val_loss: 0.1712 - val_accuracy: 0.9722
# Epoch 29/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.1565 - accuracy: 0.9965 - val_loss: 0.1490 - val_accuracy: 0.9792
# Epoch 30/50
# 5/5 [==============================] - 39s 7s/step - loss: 0.1306 - accuracy: 0.9948 - val_loss: 0.1244 - val_accuracy: 0.9861
# Epoch 31/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.1109 - accuracy: 0.9965 - val_loss: 0.1082 - val_accuracy: 0.9861
# Epoch 32/50
# 5/5 [==============================] - 43s 9s/step - loss: 0.0967 - accuracy: 0.9965 - val_loss: 0.1074 - val_accuracy: 0.9861
# Epoch 33/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.0825 - accuracy: 0.9983 - val_loss: 0.0867 - val_accuracy: 0.9861
# Epoch 34/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0730 - accuracy: 0.9983 - val_loss: 0.0861 - val_accuracy: 0.9861
# Epoch 35/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.0644 - accuracy: 0.9983 - val_loss: 0.0801 - val_accuracy: 0.9861
# Epoch 36/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0578 - accuracy: 0.9983 - val_loss: 0.0806 - val_accuracy: 0.9861
# Epoch 37/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0535 - accuracy: 0.9983 - val_loss: 0.0731 - val_accuracy: 0.9861
# Epoch 38/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.0485 - accuracy: 0.9983 - val_loss: 0.0642 - val_accuracy: 0.9931
# Epoch 39/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.0447 - accuracy: 0.9983 - val_loss: 0.0823 - val_accuracy: 0.9861
# Epoch 40/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0437 - accuracy: 0.9983 - val_loss: 0.0567 - val_accuracy: 0.9931
# Epoch 41/50
# 5/5 [==============================] - 43s 9s/step - loss: 0.0406 - accuracy: 0.9983 - val_loss: 0.0817 - val_accuracy: 0.9861
# Epoch 42/50
# 5/5 [==============================] - 37s 8s/step - loss: 0.0382 - accuracy: 0.9983 - val_loss: 0.0522 - val_accuracy: 0.9931
# Epoch 43/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0354 - accuracy: 0.9983 - val_loss: 0.0572 - val_accuracy: 0.9861
# Epoch 44/50
# 5/5 [==============================] - 38s 7s/step - loss: 0.0326 - accuracy: 0.9983 - val_loss: 0.0557 - val_accuracy: 0.9861
# Epoch 45/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.0311 - accuracy: 0.9983 - val_loss: 0.0504 - val_accuracy: 0.9931
# Epoch 46/50
# 5/5 [==============================] - 40s 8s/step - loss: 0.0295 - accuracy: 0.9983 - val_loss: 0.0584 - val_accuracy: 0.9861
# Epoch 47/50
# 5/5 [==============================] - 54s 12s/step - loss: 0.0278 - accuracy: 0.9983 - val_loss: 0.0483 - val_accuracy: 0.9931
# Epoch 48/50
# 5/5 [==============================] - 48s 9s/step - loss: 0.0264 - accuracy: 0.9983 - val_loss: 0.0562 - val_accuracy: 0.9861
# Epoch 49/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0255 - accuracy: 0.9983 - val_loss: 0.0457 - val_accuracy: 0.9931
# Epoch 50/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.0237 - accuracy: 0.9983 - val_loss: 0.0574 - val_accuracy: 0.9861

# %% [markdown]
# **Saving the model using different techniques.**

# %%
model.save("/content/drive/MyDrive/Colab Notebook/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/MyDrive/Colab Notebook/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/MyDrive/Colab Notebook/plant_model_weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **Next we will plot the accuracy of the model for the trainig history.**

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# **Evaluating the model to know the accuracy of the model.**

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 9s 1s/step - loss: 0.0415 - accuracy: 1.0000
# Test Accuracy: 100.0

# %% [markdown]
# **Next we will use our model to predict predicting the testing dataset label.**

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 8s 925ms/step

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# **Printing out the original and the predicted label.**

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# # ***Conclusion***

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
